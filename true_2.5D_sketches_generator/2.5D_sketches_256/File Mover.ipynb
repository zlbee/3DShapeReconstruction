# %%
import os, sys
import shutil
from google.colab import drive
drive.mount('/content/gdrive')
project_path = '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator'
sys.path.append(project_path)

# %%
cd /content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/normal
# Out:
# /content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/normal

# %%
source_dir = '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/normal'
dest_dir = '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/normal_1'

filenames = os.listdir(source_dir)
print(filenames)
# for filename in filenames:
#   try:
#     os.remove(os.path.join(dest_dir, filename))
#     print(filename+' removed')
#   except OSError:
#     pass

# for filename in filenames:
#   shutil.move(os.path.join(source_dir, filename), dest_dir)
#   print(filename)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-7b686495cf66>", line 4, in <module>
#     filenames = os.listdir(source_dir)
# OSError: [Errno 5] Input/output error: '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/normal'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
source_dir = '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/depth'
dest_dir = '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/depth_1'

filenames = os.listdir(source_dir)
print(filenames)
# for filename in filenames:
#   try:
#     os.remove(os.path.join(dest_dir, filename))
#     print(filename+' removed')
#   except OSError:
#     pass

# for filename in filenames:
#   shutil.move(os.path.join(source_dir, filename), dest_dir)
#   print(filename)

# %%
source_dir = '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/sihouette'
dest_dir = '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/sihouette_1'

filenames = os.listdir(source_dir)
print(filenames)
# for filename in filenames:
#   try:
#     os.remove(os.path.join(dest_dir, filename))
#     print(filename+' removed')
#   except OSError:
#     pass

# for filename in filenames:
#   shutil.move(os.path.join(source_dir, filename), dest_dir)
#   print(filename)

# %%
source_dir = '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/raw_image'
dest_dir = '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/raw_image_1'

filenames = os.listdir(source_dir)
print(filenames)
for filename in filenames:
  try:
    os.remove(os.path.join(dest_dir, filename))
    print(filename+' removed')
  except OSError:
    pass

for filename in filenames:
  shutil.move(os.path.join(source_dir, filename), dest_dir)
  print(filename)

# %%
! du -sh /content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/depth

# %%
initial_dir = '/content/gdrive/MyDrive/master/true_2.5D_sketches_generator/2.5D_sketches_256/depth'

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.8.2
